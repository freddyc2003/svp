# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the CSV file
file_path = '../hyperfine_results.csv'  # Replace with your file path
df = pd.read_csv(file_path)

# %%
# Renaming the columns for clarity
df.columns = ['Dimensionality', 'Bit Level', 'Lattice Type', 'Mean Run Time', 'Std Deviation']

# %%
# Saving the plot with 800 DPI
fig = plt.figure(figsize=(15, 5))

for i, bit_level in enumerate(bit_levels, 1):
    ax = fig.add_subplot(1, len(bit_levels), i)
    sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
    ax.set_title(f'({chr(96 + i)}) Bit Level {bit_level}')
    ax.set_xlabel('Dimensionality')
    ax.set_ylabel('Mean Run Time (s)')
    if i > 1:
        ax.set_ylabel('')

fig.tight_layout()

# Save the figure
save_path = './uniform_run_time.png'
fig.savefig(save_path, dpi=800)
# Out:
# /tmp/ipykernel_206533/2927662826.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
# /tmp/ipykernel_206533/2927662826.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
# /tmp/ipykernel_206533/2927662826.py:6: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')

# %%
# Re-creating and saving the plot with a logarithmic scale for the y-axis

fig = plt.figure(figsize=(15, 5))

for i, bit_level in enumerate(bit_levels, 1):
    ax = fig.add_subplot(1, len(bit_levels), i)
    sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
    ax.set_title(f'({chr(96 + i)}) Bit Level {bit_level}')
    ax.set_xlabel('Dimensionality')
    ax.set_ylabel('Mean Run Time (s)')
    ax.set_yscale('log')  # Applying logarithmic scale
    if i > 1:
        ax.set_ylabel('')

fig.tight_layout()

# Save the figure with logarithmic scale
# log_scale_save_path = '/mnt/data/multiplot_line_graph_log_scale.png'
# fig.savefig(log_scale_save_path, dpi=800)
# Out:
# /tmp/ipykernel_206533/1064372087.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
# /tmp/ipykernel_206533/1064372087.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
# /tmp/ipykernel_206533/1064372087.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df[df['Bit Level'] == bit_level], x='Dimensionality', y='Mean Run Time', palette='Set2')
